# %%
# !pip install pandas openpyxl

# %%
import pandas as pd

# Διαβάζει το καθαρό CSV σου κατευθείαν!
df = pd.read_csv('matrix_output_arch2.csv')

# Αν θες να το σώσεις σε Excel:
df.to_excel('matrix_results_arch2.xlsx', index=False)

# Εμφανίζει τις πρώτες 5 γραμμές
display(df.head())
# Out:
#    num_threads  iteration  matrix_size  execution_time_ms
# 0            1          0         2048              26373
# 1            1          1         2048              26303
# 2            1          2         2048              26597
# 3            1          3         2048              27073
# 4            1          4         2048              26763

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\mtsou
